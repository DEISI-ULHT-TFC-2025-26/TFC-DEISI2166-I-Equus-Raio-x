# %% [markdown]
# # TFC - iEquus - Raio-x

# %% [markdown]
# ## Imports

# %%
from utils import *

# %% [markdown]
# ## Modelo inicial

# %%
path = "treino_modelos"

# %%
modelo_origem = pd.read_csv(f"{path}/resultados_modelos_iniciais.csv")
modelo_origem.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.436945  0.435897         0.461458      0.434375
# resnet18            0.403668  0.410256         0.515104      0.406250
# vgg11               0.400157  0.410256         0.458557      0.412500
# googlenet           0.399669  0.397436         0.438542      0.400000
# convnext_small      0.365334  0.371795         0.392857      0.371875
# convnext_tiny       0.364651  0.371795         0.396478      0.375000
# resnet50            0.363641  0.371795         0.422599      0.375000
# vit                 0.340341  0.333333         0.365179      0.328125
# mobilenet_v3_small  0.335588  0.346154         0.367708      0.353125
# nasnet_large        0.332046  0.320513         0.397978      0.325000
# convnext_base       0.300855  0.307692         0.393136      0.306250
# efficientnet_v2_s   0.291629  0.307692         0.345660      0.303125
# ...

# %%
modelo_origem.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.309848  0.307692         0.325000       0.30000
# 17                 vit  0.370833  0.358974         0.405357       0.35625
# 21               vgg11  0.412463  0.435897         0.494048       0.43750
# 6                vgg11  0.387851  0.384615         0.423065       0.38750
# 13        se_resnext50  0.276091  0.307692         0.289394       0.30000
# 28        se_resnext50  0.287157  0.333333         0.283482       0.33125
# 16            resnet50  0.355880  0.358974         0.415179       0.36250
# 1             resnet50  0.371401  0.384615         0.430019       0.38750
# 0             resnet18  0.404657  0.410256         0.569792       0.40625
# 15            resnet18  0.402679  0.410256         0.460417       0.40625
# 29        nasnet_large  0.290783  0.282051         0.383456       0.28750
# 14        nasnet_large  0.373310  0.358974         0.412500       0.36250
# ...

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# ### RandomRotation(10)

# %%
augmentation1 = pd.read_csv(f"{path}/resultados_data_augmentation1.csv")
augmentation1.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.464242  0.474359         0.484375      0.468750
# vit                 0.427336  0.423077         0.451935      0.418750
# vgg11               0.379626  0.384615         0.429167      0.381250
# efficientnet_v2_m   0.365111  0.358974         0.439908      0.356250
# se_resnext50        0.332116  0.371795         0.371438      0.371875
# resnet50            0.327260  0.346154         0.401538      0.340625
# efficientnet_v2_s   0.313394  0.333333         0.310640      0.337500
# convnext_tiny       0.309939  0.320513         0.396487      0.318750
# convnext_small      0.307724  0.333333         0.328819      0.328125
# convnext_base       0.291131  0.320513         0.310764      0.315625
# mobilenet_v3_small  0.289812  0.320513         0.283259      0.325000
# nasnet_large        0.283659  0.294872         0.376414      0.296875
# ...

# %%
augmentation1.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.438005  0.435897         0.465179       0.43125
# 17                 vit  0.416667  0.410256         0.438690       0.40625
# 21               vgg11  0.382326  0.384615         0.429018       0.38125
# 6                vgg11  0.376926  0.384615         0.429315       0.38125
# 13        se_resnext50  0.330898  0.358974         0.343254       0.36250
# 28        se_resnext50  0.333333  0.384615         0.399621       0.38125
# 16            resnet50  0.315873  0.333333         0.450694       0.32500
# 1             resnet50  0.338647  0.358974         0.352381       0.35625
# 0             resnet18  0.267968  0.282051         0.286616       0.28125
# 15            resnet18  0.284425  0.333333         0.289583       0.33750
# 29        nasnet_large  0.278510  0.282051         0.446875       0.28125
# 14        nasnet_large  0.288808  0.307692         0.305952       0.31250
# ...

# %% [markdown]
# ### ColorJitter

# %%
augmentation2 = pd.read_csv(f"{path}/resultados_data_augmentation2.csv")
augmentation2.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.436706  0.435897         0.462723      0.431250
# convnext_tiny       0.408354  0.423077         0.420536      0.421875
# googlenet           0.406088  0.410256         0.483545      0.415625
# resnet18            0.400991  0.423077         0.496834      0.418750
# vgg11               0.395572  0.410256         0.463542      0.409375
# mobilenet_v3_small  0.379771  0.384615         0.433408      0.387500
# resnet50            0.367623  0.371795         0.470245      0.368750
# convnext_small      0.352505  0.333333         0.417903      0.334375
# vit                 0.336963  0.333333         0.359673      0.331250
# efficientnet_v2_m   0.321007  0.346154         0.334159      0.337500
# convnext_base       0.296857  0.358974         0.298723      0.350000
# se_resnext50        0.296340  0.307692         0.350805      0.306250
# ...

# %%
augmentation2.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.356250  0.358974         0.374405       0.35625
# 17                 vit  0.317677  0.307692         0.344940       0.30625
# 21               vgg11  0.379293  0.384615         0.422917       0.38125
# 6                vgg11  0.411851  0.435897         0.504167       0.43750
# 13        se_resnext50  0.295405  0.307692         0.319508       0.30625
# 28        se_resnext50  0.297276  0.307692         0.382102       0.30625
# 16            resnet50  0.356498  0.358974         0.397781       0.35625
# 1             resnet50  0.378749  0.384615         0.542708       0.38125
# 0             resnet18  0.405005  0.435897         0.549621       0.43125
# 15            resnet18  0.396977  0.410256         0.444048       0.40625
# 29        nasnet_large  0.288393  0.282051         0.318561       0.28750
# 14        nasnet_large  0.302976  0.333333         0.391667       0.33125
# ...

# %% [markdown]
# ### RandomResizedCrop

# %%
augmentation3 = pd.read_csv(f"{path}/resultados_data_augmentation3.csv")
augmentation3.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.471392  0.474359         0.495536      0.468750
# resnet18            0.384664  0.397436         0.459524      0.403125
# resnet50            0.382047  0.397436         0.484512      0.387500
# vgg11               0.381967  0.397436         0.392911      0.393750
# convnext_tiny       0.351937  0.358974         0.377951      0.365625
# se_resnext50        0.340345  0.358974         0.363479      0.353125
# efficientnet_v2_m   0.335033  0.346154         0.372173      0.337500
# densenet121         0.319311  0.333333         0.362843      0.331250
# convnext_base       0.302264  0.320513         0.309276      0.315625
# vit                 0.302217  0.320513         0.309821      0.312500
# convnext_small      0.289537  0.294872         0.376786      0.293750
# googlenet           0.277697  0.294872         0.312184      0.287500
# ...

# %%
augmentation3.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.322917  0.333333         0.347321       0.32500
# 17                 vit  0.281517  0.307692         0.272321       0.30000
# 21               vgg11  0.387942  0.410256         0.383929       0.40625
# 6                vgg11  0.375992  0.384615         0.401894       0.38125
# 13        se_resnext50  0.334098  0.358974         0.350063       0.35625
# 28        se_resnext50  0.346591  0.358974         0.376894       0.35000
# 16            resnet50  0.388447  0.410256         0.478846       0.40000
# 1             resnet50  0.375647  0.384615         0.490179       0.37500
# 0             resnet18  0.386204  0.410256         0.417262       0.41875
# 15            resnet18  0.383124  0.384615         0.501786       0.38750
# 29        nasnet_large  0.252110  0.282051         0.246338       0.28125
# 14        nasnet_large  0.279310  0.307692         0.390774       0.30000
# ...

# %% [markdown]
# ### RandomHorizontalFlip

# %%
augmentation4 = pd.read_csv(f"{path}/resultados_data_augmentation4.csv")
augmentation4.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# googlenet           0.380916  0.397436         0.393700      0.387500
# resnet18            0.378274  0.384615         0.509240      0.381250
# vgg11               0.362516  0.371795         0.426910      0.368750
# convnext_tiny       0.350812  0.371795         0.350645      0.371875
# dino_vit            0.338093  0.358974         0.341344      0.359375
# vit                 0.337204  0.320513         0.379715      0.318750
# nasnet_large        0.330510  0.294872         0.414757      0.300000
# efficientnet_v2_m   0.325271  0.333333         0.370387      0.334375
# mobilenet_v3_small  0.318998  0.346154         0.354836      0.350000
# resnet50            0.302937  0.307692         0.335789      0.306250
# se_resnext50        0.298662  0.294872         0.321503      0.287500
# efficientnet_v2_s   0.297605  0.307692         0.312128      0.312500
# ...

# %%
augmentation4.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.326491  0.307692         0.375149       0.30625
# 17                 vit  0.347917  0.333333         0.384280       0.33125
# 21               vgg11  0.369156  0.358974         0.423611       0.35625
# 6                vgg11  0.355876  0.384615         0.430208       0.38125
# 13        se_resnext50  0.279963  0.282051         0.296875       0.27500
# 28        se_resnext50  0.317361  0.307692         0.346131       0.30000
# 16            resnet50  0.293290  0.307692         0.318452       0.30000
# 1             resnet50  0.312584  0.307692         0.353125       0.31250
# 0             resnet18  0.383631  0.384615         0.564015       0.38125
# 15            resnet18  0.372917  0.384615         0.454464       0.38125
# 29        nasnet_large  0.327291  0.282051         0.420139       0.28750
# 14        nasnet_large  0.333730  0.307692         0.409375       0.31250
# ...

# %% [markdown]
# ### RandomAffine

# %%
augmentation5 = pd.read_csv(f"{path}/resultados_data_augmentation5.csv")
augmentation5.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.487477  0.512821         0.491716      0.506250
# vit                 0.399911  0.397436         0.464807      0.393750
# vgg11               0.385730  0.397436         0.418775      0.393750
# efficientnet_v2_m   0.377264  0.384615         0.485227      0.384375
# convnext_small      0.361723  0.371795         0.387500      0.375000
# resnet50            0.354613  0.384615         0.396532      0.381250
# convnext_tiny       0.349826  0.346154         0.397644      0.346875
# resnet18            0.329202  0.358974         0.350710      0.371875
# efficientnet_v2_s   0.321533  0.333333         0.332614      0.334375
# mobilenet_v3_small  0.307521  0.346154         0.312624      0.350000
# nasnet_large        0.301686  0.320513         0.301116      0.325000
# convnext_base       0.285801  0.320513         0.283917      0.315625
# ...

# %%
augmentation5.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.404870  0.410256         0.482738       0.40625
# 17                 vit  0.394952  0.384615         0.446875       0.38125
# 21               vgg11  0.422430  0.435897         0.451786       0.43125
# 6                vgg11  0.349031  0.358974         0.385764       0.35625
# 13        se_resnext50  0.270530  0.307692         0.372024       0.30625
# 28        se_resnext50  0.295356  0.307692         0.319508       0.31250
# 16            resnet50  0.310317  0.333333         0.342370       0.33750
# 1             resnet50  0.398909  0.435897         0.450694       0.42500
# 0             resnet18  0.324278  0.358974         0.346496       0.37500
# 15            resnet18  0.334127  0.358974         0.354924       0.36875
# 29        nasnet_large  0.307044  0.307692         0.329167       0.31875
# 14        nasnet_large  0.296329  0.333333         0.273065       0.33125
# ...

# %% [markdown]
# ### AutoAugment

# %%
augmentation6 = pd.read_csv(f"{path}/resultados_data_augmentation6.csv")
augmentation6.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.469296  0.474359         0.492708      0.468750
# resnet18            0.427841  0.448718         0.541555      0.446875
# vgg11               0.423222  0.423077         0.484673      0.421875
# vit                 0.399702  0.410256         0.411979      0.406250
# convnext_tiny       0.385433  0.397436         0.420610      0.393750
# googlenet           0.363465  0.371795         0.451786      0.368750
# convnext_small      0.341909  0.371795         0.391022      0.368750
# resnet50            0.341041  0.333333         0.406324      0.331250
# nasnet_large        0.335035  0.320513         0.408507      0.321875
# se_resnext50        0.330979  0.358974         0.381834      0.350000
# mobilenet_v3_small  0.325751  0.358974         0.347594      0.356250
# densenet121         0.307904  0.333333         0.331399      0.331250
# ...

# %%
augmentation6.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.403517  0.410256         0.411905       0.40625
# 17                 vit  0.395887  0.410256         0.412054       0.40625
# 21               vgg11  0.412843  0.410256         0.460714       0.40625
# 6                vgg11  0.433600  0.435897         0.508631       0.43750
# 13        se_resnext50  0.320833  0.358974         0.309821       0.35000
# 28        se_resnext50  0.341126  0.358974         0.453846       0.35000
# 16            resnet50  0.307485  0.307692         0.415774       0.30000
# 1             resnet50  0.374597  0.358974         0.396875       0.36250
# 0             resnet18  0.450126  0.461538         0.580729       0.46250
# 15            resnet18  0.405556  0.435897         0.502381       0.43125
# 29        nasnet_large  0.352895  0.333333         0.451389       0.33750
# 14        nasnet_large  0.317174  0.307692         0.365625       0.30625
# ...

# %% [markdown]
# ### Augmentation Final 1

# %%
augmentation_final1 = pd.read_csv(f"aug_f1/resultados_data_augmentation_final1.csv")
augmentation_final1.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.425237  0.435897         0.484512      0.431250
# convnext_tiny       0.375027  0.384615         0.376141      0.384375
# efficientnet_v2_m   0.368267  0.397436         0.419841      0.387500
# convnext_small      0.352878  0.371795         0.407589      0.368750
# googlenet           0.337451  0.358974         0.450620      0.356250
# resnet18            0.331559  0.358974         0.369623      0.368750
# mobilenet_v3_small  0.324148  0.358974         0.319841      0.350000
# efficientnet_v2_s   0.320892  0.307692         0.473264      0.306250
# vit                 0.314795  0.333333         0.396949      0.328125
# resnet50            0.311072  0.358974         0.361298      0.350000
# vgg11               0.303242  0.307692         0.383333      0.303125
# se_resnext50        0.298291  0.333333         0.332624      0.325000
# ...

# %%
augmentation_final1.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.317541  0.358974         0.387153       0.35625
# 17                 vit  0.312049  0.307692         0.406746       0.30000
# 21               vgg11  0.313303  0.307692         0.401488       0.30625
# 6                vgg11  0.293182  0.307692         0.365179       0.30000
# 13        se_resnext50  0.310157  0.358974         0.342628       0.35000
# 28        se_resnext50  0.286425  0.307692         0.322619       0.30000
# 16            resnet50  0.309452  0.358974         0.391346       0.35000
# 1             resnet50  0.312693  0.358974         0.331250       0.35000
# 0             resnet18  0.375992  0.410256         0.372768       0.41875
# 15            resnet18  0.287126  0.307692         0.366477       0.31875
# 29        nasnet_large  0.278003  0.307692         0.282738       0.30000
# 14        nasnet_large  0.300253  0.307692         0.306250       0.30000
# ...

# %% [markdown]
# ### Augmentation Final 2

# %%
augmentation_final2 = pd.read_csv(f"aug_f2/resultados_data_augmentation_final2.csv")
augmentation_final2.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.428775  0.448718         0.544769      0.443750
# efficientnet_v2_m   0.378750  0.371795         0.546007      0.368750
# vgg11               0.342936  0.371795         0.369469      0.368750
# vit                 0.341189  0.346154         0.380556      0.340625
# convnext_tiny       0.340080  0.346154         0.414211      0.350000
# mobilenet_v3_small  0.337444  0.384615         0.361657      0.381250
# se_resnext50        0.320524  0.346154         0.378869      0.350000
# efficientnet_v2_s   0.302751  0.320513         0.352841      0.321875
# resnet18            0.301557  0.333333         0.319246      0.340625
# convnext_base       0.292889  0.320513         0.304613      0.315625
# nasnet_large        0.283401  0.294872         0.311269      0.290625
# googlenet           0.283005  0.294872         0.359876      0.300000
# ...

# %%
augmentation_final2.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.335444  0.358974         0.350099       0.35000
# 17                 vit  0.346934  0.333333         0.411012       0.33125
# 21               vgg11  0.332166  0.358974         0.362054       0.35625
# 6                vgg11  0.353707  0.384615         0.376885       0.38125
# 13        se_resnext50  0.361188  0.384615         0.451488       0.39375
# 28        se_resnext50  0.279861  0.307692         0.306250       0.30625
# 16            resnet50  0.279383  0.333333         0.320833       0.32500
# 1             resnet50  0.258306  0.307692         0.255506       0.30000
# 0             resnet18  0.316241  0.333333         0.352381       0.34375
# 15            resnet18  0.286874  0.333333         0.286111       0.33750
# 29        nasnet_large  0.310764  0.333333         0.315341       0.32500
# 14        nasnet_large  0.256039  0.256410         0.307197       0.25625
# ...

# %% [markdown]
# ### Augmentation Final 3

# %%
augmentation_final3 = pd.read_csv(f"aug_f3/resultados_data_augmentation_final3.csv")
augmentation_final3.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.487329  0.500000         0.517113      0.493750
# resnet18            0.450958  0.461538         0.552827      0.465625
# vit                 0.376429  0.371795         0.430878      0.368750
# efficientnet_v2_s   0.370517  0.358974         0.409797      0.362500
# vgg11               0.369381  0.358974         0.485897      0.356250
# resnet50            0.349710  0.358974         0.411458      0.356250
# convnext_tiny       0.341538  0.371795         0.354248      0.362500
# convnext_small      0.339931  0.358974         0.354924      0.350000
# nasnet_large        0.319542  0.333333         0.341667      0.331250
# mobilenet_v3_small  0.314502  0.333333         0.394792      0.331250
# se_resnext50        0.312859  0.346154         0.419929      0.337500
# convnext_base       0.293651  0.307692         0.335714      0.300000
# ...

# %%
augmentation_final3.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.392838  0.384615         0.451042       0.38125
# 17                 vit  0.360020  0.358974         0.410714       0.35625
# 6                vgg11  0.369381  0.358974         0.485897       0.35625
# 22        se_resnext50  0.310471  0.333333         0.376984       0.32500
# 13        se_resnext50  0.315247  0.358974         0.462874       0.35000
# 1             resnet50  0.372962  0.384615         0.391667       0.38125
# 16            resnet50  0.326459  0.333333         0.431250       0.33125
# 15            resnet18  0.447238  0.461538         0.535714       0.46250
# 0             resnet18  0.454678  0.461538         0.569940       0.46875
# 14        nasnet_large  0.319542  0.333333         0.341667       0.33125
# 3   mobilenet_v3_small  0.314502  0.333333         0.394792       0.33125
# 4            googlenet  0.285181  0.307692         0.314137       0.30000
# ...

# %% [markdown]
# ### Augmentation Final 4

# %%
augmentation_final4 = pd.read_csv(f"aug_f4/resultados_data_augmentation_final4.csv")
augmentation_final4.groupby("nome").mean().sort_values(by="f1_macro", ascending=False)
# Out:
#                     f1_macro  accuracy  precision_macro  recall_macro  \
# nome
# dino_vit            0.445576  0.461538         0.529694      0.456250
# mobilenet_v3_small  0.389320  0.410256         0.417535      0.412500
# vit                 0.373323  0.358974         0.441815      0.356250
# vgg11               0.331093  0.384615         0.314931      0.381250
# convnext_tiny       0.325298  0.333333         0.356944      0.331250
# efficientnet_v2_m   0.319909  0.358974         0.392262      0.353125
# efficientnet_v2_s   0.309876  0.320513         0.331052      0.321875
# se_resnext50        0.304744  0.333333         0.330580      0.331250
# resnet50            0.302350  0.358974         0.359890      0.350000
# googlenet           0.293750  0.307692         0.368615      0.318750
# resnet18            0.290190  0.307692         0.341518      0.306250
# convnext_small      0.286932  0.307692         0.354167      0.300000
# ...

# %%
augmentation_final4.sort_values(by=["nome"], ascending=False)
# Out:
#                   nome  f1_macro  accuracy  precision_macro  recall_macro  \
# 2                  vit  0.369453  0.358974         0.447024       0.35625
# 15                 vit  0.377192  0.358974         0.436607       0.35625
# 6                vgg11  0.331093  0.384615         0.314931       0.38125
# 20        se_resnext50  0.281755  0.307692         0.291964       0.30625
# 13        se_resnext50  0.327732  0.358974         0.369196       0.35625
# 1             resnet50  0.302350  0.358974         0.359890       0.35000
# 0             resnet18  0.290190  0.307692         0.341518       0.30625
# 14        nasnet_large  0.284206  0.307692         0.293750       0.30000
# 3   mobilenet_v3_small  0.391865  0.410256         0.421230       0.41250
# 16  mobilenet_v3_small  0.386774  0.410256         0.413839       0.41250
# 4            googlenet  0.293750  0.307692         0.368615       0.31875
# 18   efficientnet_v2_s  0.318362  0.333333         0.341270       0.33125
# ...
