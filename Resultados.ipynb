# %% [markdown]
# ## Resultados, ultima fase

# %%
from utils import *

# %% [markdown]
# ## Tabelas

# %%
read_results(variavel_tipo= "augmentation")
# Out:
#            f1_macro  accuracy  precision_macro  recall_macro  best_epoch  \
# nome
# YOLOn      0.898678  0.897436         0.914530      0.897222         NaN
# YOLOm      0.898496  0.897436         0.901768      0.900000         NaN
# resnet18   0.810644  0.820513         0.862689      0.819444        90.0
# dino_vit   0.801053  0.794872         0.844444      0.791667        68.0
# vgg11      0.794737  0.794872         0.797222      0.794444        56.0
# googlenet  0.749415  0.743590         0.753535      0.747222        66.0
# vit        0.712535  0.717949         0.713068      0.713889        41.0
#
#                  nome_var
# nome
# YOLOn      augmentation_6
# YOLOm      augmentation_6
# resnet18         controlo
# dino_vit   augmentation_5
# vgg11      augmentation_5
# googlenet  augmentation_2
# vit        augmentation_6

# %%
read_results(variavel_tipo= "optimizer")
# Out:
#            f1_macro  accuracy  precision_macro  recall_macro  best_epoch  \
# nome
# YOLOn      0.898678  0.897436         0.914530      0.897222         NaN
# YOLOm      0.898496  0.897436         0.901768      0.900000         NaN
# dino_vit   0.823594  0.820513         0.875000      0.816667        53.0
# resnet18   0.810644  0.820513         0.862689      0.819444        90.0
# googlenet  0.796053  0.794872         0.801263      0.797222        65.0
# vgg11      0.794737  0.794872         0.797222      0.794444        56.0
# vit        0.738722  0.743590         0.737374      0.741667        51.0
#
#                         nome_var
# nome
# YOLOn      optimizer_AdamW_0.001
# YOLOm      optimizer_AdamW_0.001
# dino_vit    optimizer_AdamW_0.01
# resnet18   optimizer_AdamW_0.001
# googlenet     optimizer_SGD_0.01
# vgg11      optimizer_AdamW_0.001
# vit          optimizer_SGD_0.001

# %%
read_results(variavel_tipo= "scheduler")
# Out:
#            f1_macro  accuracy  precision_macro  recall_macro  best_epoch  \
# nome
# YOLOm      0.924908  0.923077         0.942308      0.922222         NaN
# YOLOn      0.898678  0.897436         0.914530      0.897222         NaN
# dino_vit   0.823594  0.820513         0.875000      0.816667        53.0
# resnet18   0.810644  0.820513         0.862689      0.819444        90.0
# googlenet  0.796053  0.794872         0.801263      0.797222        65.0
# vgg11      0.794737  0.794872         0.797222      0.794444        56.0
# vit        0.738722  0.743590         0.737374      0.741667        51.0
#
#                               nome_var
# nome
# YOLOm      scheduler_CosineAnnealingLR
# YOLOn                   scheduler_None
# dino_vit                scheduler_None
# resnet18                scheduler_None
# googlenet               scheduler_None
# vgg11                   scheduler_None
# vit                     scheduler_None

# %%
read_results(variavel_tipo= "lossFunction")
# Out:
#            f1_macro  accuracy  precision_macro  recall_macro  best_epoch  \
# nome
# resnet18   0.838889  0.846154         0.888889      0.847222          48
# dino_vit   0.823594  0.820513         0.875000      0.816667          53
# vgg11      0.817043  0.820513         0.818939      0.819444          84
# googlenet  0.796053  0.794872         0.801263      0.797222          65
# vit        0.738722  0.743590         0.737374      0.741667          51
#
#                             nome_var
# nome
# resnet18            lossFunction_mse
# dino_vit   lossFunction_crossEntropy
# vgg11               lossFunction_mse
# googlenet  lossFunction_crossEntropy
# vit        lossFunction_crossEntropy

# %% [markdown]
# ## Testes

# %%
img1="IMG_teste1.png"
img = Image.open(img1)
plt.imshow(img)
plt.axis('off')
plt.show()
classify_image(img1)
# Out:
# image 1/1 c:\Users\Utilizador\Documents\BACKUP MAT\Manter\Faculdade\3 ano\Trabalho final de curso\Codigos\IMG_teste1.png: 224x224 Ant_DP10_PaDO 0.44, Ant_D45L_PaMO 0.37, Ant_LM 0.18, Ant_D45M_PaLO 0.00, 8.3ms
# Speed: 19.1ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 'Imagem inválida'

# %%
img1="IMG_teste2.png"
img = Image.open(img1)
plt.imshow(img)
plt.axis('off')
plt.show()
classify_image(img1)
# Out:
# image 1/1 c:\Users\Utilizador\Documents\BACKUP MAT\Manter\Faculdade\3 ano\Trabalho final de curso\Codigos\IMG_teste2.png: 224x224 Ant_DP10_PaDO 0.81, Ant_D45M_PaLO 0.10, Ant_D45L_PaMO 0.05, Ant_LM 0.03, 7.7ms
# Speed: 8.4ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Classe: Ant_DP10_PaDO

# %%
img1="IMG_teste3.png"
img = Image.open(img1)
plt.imshow(img)
plt.axis('off')
plt.show()
classify_image(img1)
# Out:
# image 1/1 c:\Users\Utilizador\Documents\BACKUP MAT\Manter\Faculdade\3 ano\Trabalho final de curso\Codigos\IMG_teste3.png: 224x224 Ant_LM 1.00, Ant_D45L_PaMO 0.00, Ant_D45M_PaLO 0.00, Ant_DP10_PaDO 0.00, 48.7ms
# Speed: 3.0ms preprocess, 48.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Classe: Ant_LM

# %%
img1="IMG_teste4.png"
img = Image.open(img1)
plt.imshow(img)
plt.axis('off')
plt.show()
classify_image(img1)
# Out:
# image 1/1 c:\Users\Utilizador\Documents\BACKUP MAT\Manter\Faculdade\3 ano\Trabalho final de curso\Codigos\IMG_teste4.png: 224x224 Ant_LM 0.99, Ant_D45M_PaLO 0.00, Ant_D45L_PaMO 0.00, Ant_DP10_PaDO 0.00, 49.0ms
# Speed: 3.8ms preprocess, 49.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Classe: Ant_LM

# %%
img1="IMG_teste5.png"
img = Image.open(img1)
plt.imshow(img)
plt.axis('off')
plt.show()
classify_image(img1)
# Out:
# image 1/1 c:\Users\Utilizador\Documents\BACKUP MAT\Manter\Faculdade\3 ano\Trabalho final de curso\Codigos\IMG_teste5.png: 224x224 Ant_D45L_PaMO 0.74, Ant_D45M_PaLO 0.22, Ant_LM 0.03, Ant_DP10_PaDO 0.01, 48.6ms
# Speed: 2.3ms preprocess, 48.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 'Imagem inválida'
